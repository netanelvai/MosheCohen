# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv("C:\\Users\\jbt\\Downloads\\T_2_Q_7328682271_python_datasets_20220211T121836Z_001\\python_datasets\\movie_titles.tsv",sep='\t')
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
d1=pd.read_csv("C:\\Users\\jbt\\python\\data\\billionaires_2019.csv")
d2=pd.read_csv("C:\\Users\\jbt\\python\\data\\billionaires_2020.csv")
d3=pd.read_csv("C:\\Users\\jbt\\python\\data\\billionaires_2021.csv")
d4=pd.read_csv("C:\\Users\\jbt\\python\\data\\billionaires_2022.csv")
d5=pd.read_csv("C:\\Users\\jbt\\python\\data\\billionaires_2023.csv")

# %%
#df=pd.concat(d1,d2,d3,d4,d5)
d4
# Out:
#       year  month  rank net_worth last_name first_name  \
# 0     2022      4     1   219.0 B      Musk       Elon
# 1     2022      4     2   171.0 B     Bezos       Jeff
# 2     2022      4     3   158.0 B   Arnault    Bernard
# 3     2022      4     4   129.0 B     Gates       Bill
# 4     2022      4     5   118.0 B   Buffett     Warren
# ...    ...    ...   ...       ...       ...        ...
# 2663  2022      4  2578     1.0 B     Zhang    Yuqiang
# 2664  2022      4  2578     1.0 B      Zhou      Ruxin
# 2665  2022      4  2578     1.0 B      Zhou        Wen
# 2666  2022      4  2578     1.0 B      Zhou     Yifeng
# 2667  2022      4  2578     1.0 B    Zhuang    Kuilong
#
#                      full_name  birth_date   age  gender  \
# 0                    Elon Musk  1971-06-28  50.0    Male
# 1                   Jeff Bezos  1964-01-12  58.0    Male
# 2     Bernard Arnault & family  1949-03-05  73.0    Male
# 3                   Bill Gates  1955-10-28  66.0    Male
# ...

# %%
d5
# Out:
#       year  month  rank net_worth  last_name first_name  \
# 0     2023      4     1   211.0 B    Arnault    Bernard
# 1     2023      4     2   180.0 B       Musk       Elon
# 2     2023      4     3   114.0 B      Bezos       Jeff
# 3     2023      4     4   107.0 B    Ellison      Larry
# 4     2023      4     5   106.0 B    Buffett     Warren
# ...    ...    ...   ...       ...        ...        ...
# 2635  2023      4  2540     1.0 B         Yu       Rong
# 2636  2023      4  2540     1.0 B  Yuengling    Richard
# 2637  2023      4  2540     1.0 B      Zhang    Gongyun
# 2638  2023      4  2540     1.0 B      Zhang    Guiping
# 2639  2023      4  2540     1.0 B      Zobel      Inigo
#
#                      full_name  birth_date   age gender  \
# 0     Bernard Arnault & family  1949-03-05  74.0   Male
# 1                    Elon Musk  1971-06-28  51.0   Male
# 2                   Jeff Bezos  1964-01-12  59.0   Male
# 3                Larry Ellison  1944-08-17  78.0   Male
# ...

# %%
df=pd.concat([d1,d2,d3,d4,d5])

# %%
df
# Out:
#       year  month  rank net_worth  last_name first_name  \
# 0     2019      3     1   131.0 B      Bezos       Jeff
# 1     2019      3     2    96.5 B      Gates       Bill
# 2     2019      3     3    82.5 B    Buffett     Warren
# 3     2019      3     4    76.0 B    Arnault    Bernard
# 4     2019      3     5    64.0 B  Slim Helu     Carlos
# ...    ...    ...   ...       ...        ...        ...
# 2635  2023      4  2540     1.0 B         Yu       Rong
# 2636  2023      4  2540     1.0 B  Yuengling    Richard
# 2637  2023      4  2540     1.0 B      Zhang    Gongyun
# 2638  2023      4  2540     1.0 B      Zhang    Guiping
# 2639  2023      4  2540     1.0 B      Zobel      Inigo
#
#                       full_name  birth_date   age gender  \
# 0                    Jeff Bezos  1964-01-12  55.0   Male
# 1                    Bill Gates  1955-10-28  63.0   Male
# 2                Warren Buffett  1930-08-30  88.0   Male
# 3      Bernard Arnault & family  1949-03-05  70.0   Male
# ...

# %%
df.shape
# Out:
# (12311, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12311 entries, 0 to 2639
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      12311 non-null  int64
#  1   month                     12311 non-null  int64
#  2   rank                      12311 non-null  int64
#  3   net_worth                 12311 non-null  object
#  4   last_name                 12311 non-null  object
#  5   first_name                12286 non-null  object
#  6   full_name                 12311 non-null  object
#  7   birth_date                11966 non-null  object
#  8   age                       11992 non-null  float64
#  9   gender                    12266 non-null  object
#  10  country_of_citizenship    12311 non-null  object
#  11  country_of_residence      12234 non-null  object
#  12  city_of_residence         12098 non-null  object
# ...

# %%
df['net_worth']=df['net_worth'].str.replace('B','')

# %%
df
# Out:
#       year  month  rank net_worth  last_name first_name  \
# 0     2019      3     1    131.0       Bezos       Jeff
# 1     2019      3     2     96.5       Gates       Bill
# 2     2019      3     3     82.5     Buffett     Warren
# 3     2019      3     4     76.0     Arnault    Bernard
# 4     2019      3     5     64.0   Slim Helu     Carlos
# ...    ...    ...   ...       ...        ...        ...
# 2635  2023      4  2540      1.0          Yu       Rong
# 2636  2023      4  2540      1.0   Yuengling    Richard
# 2637  2023      4  2540      1.0       Zhang    Gongyun
# 2638  2023      4  2540      1.0       Zhang    Guiping
# 2639  2023      4  2540      1.0       Zobel      Inigo
#
#                       full_name  birth_date   age gender  \
# 0                    Jeff Bezos  1964-01-12  55.0   Male
# 1                    Bill Gates  1955-10-28  63.0   Male
# 2                Warren Buffett  1930-08-30  88.0   Male
# 3      Bernard Arnault & family  1949-03-05  70.0   Male
# ...

# %%
df['net_worth']=df['net_worth'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12311 entries, 0 to 2639
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      12311 non-null  int64
#  1   month                     12311 non-null  int64
#  2   rank                      12311 non-null  int64
#  3   net_worth                 12311 non-null  float64
#  4   last_name                 12311 non-null  object
#  5   first_name                12286 non-null  object
#  6   full_name                 12311 non-null  object
#  7   birth_date                11966 non-null  object
#  8   age                       11992 non-null  float64
#  9   gender                    12266 non-null  object
#  10  country_of_citizenship    12311 non-null  object
#  11  country_of_residence      12234 non-null  object
#  12  city_of_residence         12098 non-null  object
# ...

# %%
df.rename(columns={'net_worth':'net_worth(B)'},inplace=True)

# %%
df
# Out:
#       year  month  rank  net_worth(B)  last_name first_name  \
# 0     2019      3     1         131.0      Bezos       Jeff
# 1     2019      3     2          96.5      Gates       Bill
# 2     2019      3     3          82.5    Buffett     Warren
# 3     2019      3     4          76.0    Arnault    Bernard
# 4     2019      3     5          64.0  Slim Helu     Carlos
# ...    ...    ...   ...           ...        ...        ...
# 2635  2023      4  2540           1.0         Yu       Rong
# 2636  2023      4  2540           1.0  Yuengling    Richard
# 2637  2023      4  2540           1.0      Zhang    Gongyun
# 2638  2023      4  2540           1.0      Zhang    Guiping
# 2639  2023      4  2540           1.0      Zobel      Inigo
#
#                       full_name  birth_date   age gender  \
# 0                    Jeff Bezos  1964-01-12  55.0   Male
# 1                    Bill Gates  1955-10-28  63.0   Male
# 2                Warren Buffett  1930-08-30  88.0   Male
# ...

# %%
df.isna().sum()
# Out:
# year                            0
# month                           0
# rank                            0
# net_worth(B)                    0
# last_name                       0
# first_name                     25
# full_name                       0
# birth_date                    345
# age                           319
# gender                         45
# country_of_citizenship          0
# country_of_residence           77
# city_of_residence             213
# business_category               1
# business_industries             1
# organization_name           10613
# position_in_organization    10486
# self_made                       0
# wealth_status                1350
# dtype: int64

# %%
df=df.drop(['organization_name','position_in_organization','first_name','last_name'],axis=1)

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  1964-01-12
# 1     2019      3     2          96.5                 Bill Gates  1955-10-28
# 2     2019      3     3          82.5             Warren Buffett  1930-08-30
# 3     2019      3     4          76.0   Bernard Arnault & family  1949-03-05
# 4     2019      3     5          64.0  Carlos Slim Helu & family  1940-01-28
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  1971-12-14
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  1943-03-10
# 2637  2023      4  2540           1.0              Zhang Gongyun  1962-12-18
# 2638  2023      4  2540           1.0     Zhang Guiping & family  1951-08-21
# 2639  2023      4  2540           1.0                Inigo Zobel  1956-11-01
#
# ...

# %%
df.isna().sum()
# Out:
# year                         0
# month                        0
# rank                         0
# net_worth(B)                 0
# full_name                    0
# birth_date                 345
# age                        319
# gender                      45
# country_of_citizenship       0
# country_of_residence        77
# city_of_residence          213
# business_category            1
# business_industries          1
# self_made                    0
# wealth_status             1350
# dtype: int64

# %%
#how to remove rows with NaN values
df.dropna(subset=['birth_date','gender','country_of_residence','city_of_residence','wealth_status'],inplace=True)

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  1964-01-12
# 1     2019      3     2          96.5                 Bill Gates  1955-10-28
# 2     2019      3     3          82.5             Warren Buffett  1930-08-30
# 3     2019      3     4          76.0   Bernard Arnault & family  1949-03-05
# 4     2019      3     5          64.0  Carlos Slim Helu & family  1940-01-28
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  1971-12-14
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  1943-03-10
# 2637  2023      4  2540           1.0              Zhang Gongyun  1962-12-18
# 2638  2023      4  2540           1.0     Zhang Guiping & family  1951-08-21
# 2639  2023      4  2540           1.0                Inigo Zobel  1956-11-01
#
# ...

# %%
df.isna().sum()
# Out:
# year                      0
# month                     0
# rank                      0
# net_worth(B)              0
# full_name                 0
# birth_date                0
# age                       6
# gender                    0
# country_of_citizenship    0
# country_of_residence      0
# city_of_residence         0
# business_category         1
# business_industries       1
# self_made                 0
# wealth_status             0
# dtype: int64

# %%
avg=df['age'].mean()

# %%
avg
# Out:
# np.float64(65.08692779613025)

# %%
df['age'].fillna(avg,inplace=True)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_29792\2394032642.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(avg,inplace=True)

# %%
df.isna().sum()
# Out:
# year                      0
# month                     0
# rank                      0
# net_worth(B)              0
# full_name                 0
# birth_date                0
# age                       0
# gender                    0
# country_of_citizenship    0
# country_of_residence      0
# city_of_residence         0
# business_category         1
# business_industries       1
# self_made                 0
# wealth_status             0
# dtype: int64

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  1964-01-12
# 1     2019      3     2          96.5                 Bill Gates  1955-10-28
# 2     2019      3     3          82.5             Warren Buffett  1930-08-30
# 3     2019      3     4          76.0   Bernard Arnault & family  1949-03-05
# 4     2019      3     5          64.0  Carlos Slim Helu & family  1940-01-28
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  1971-12-14
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  1943-03-10
# 2637  2023      4  2540           1.0              Zhang Gongyun  1962-12-18
# 2638  2023      4  2540           1.0     Zhang Guiping & family  1951-08-21
# 2639  2023      4  2540           1.0                Inigo Zobel  1956-11-01
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10601 entries, 0 to 2639
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    10601 non-null  int64
#  1   month                   10601 non-null  int64
#  2   rank                    10601 non-null  int64
#  3   net_worth(B)            10601 non-null  float64
#  4   full_name               10601 non-null  object
#  5   birth_date              10601 non-null  object
#  6   age                     10601 non-null  float64
#  7   gender                  10601 non-null  object
#  8   country_of_citizenship  10601 non-null  object
#  9   country_of_residence    10601 non-null  object
#  10  city_of_residence       10601 non-null  object
#  11  business_category       10600 non-null  object
#  12  business_industries     10600 non-null  object
#  13  self_made               10601 non-null  bool
# ...

# %%
df['birth_date']=pd.to_datetime(df['birth_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10601 entries, 0 to 2639
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    10601 non-null  int64
#  1   month                   10601 non-null  int64
#  2   rank                    10601 non-null  int64
#  3   net_worth(B)            10601 non-null  float64
#  4   full_name               10601 non-null  object
#  5   birth_date              10601 non-null  datetime64[ns]
#  6   age                     10601 non-null  float64
#  7   gender                  10601 non-null  object
#  8   country_of_citizenship  10601 non-null  object
#  9   country_of_residence    10601 non-null  object
#  10  city_of_residence       10601 non-null  object
#  11  business_category       10600 non-null  object
#  12  business_industries     10600 non-null  object
#  13  self_made               10601 non-null  bool
# ...

# %%
df['birth_date']=df['birth_date'].dt.strftime('%d/%m/%Y')

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10601 entries, 0 to 2639
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 10601 non-null  float64
# dtypes: float64(1)
# memory usage: 165.6 KB

# %%
#change a colomn type (float to int)
df['age']=df['age'].astype('int')

# %%
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10601 entries, 0 to 2639
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 10601 non-null  int64
# dtypes: int64(1)
# memory usage: 165.6 KB

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
#how to change values in specific column:
df['business_category'].replace({'Finance and Investments':'Fin&Inv','Food & Beverage':'food'})
# Out:
# 0             Technology
# 1             Technology
# 2                Fin&Inv
# 3       Fashion & Retail
# 4                Telecom
#               ...
# 2635          Healthcare
# 2636                food
# 2637       Manufacturing
# 2638         Real Estate
# 2639         Diversified
# Name: business_category, Length: 10601, dtype: object

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df['business_category'].replace({'Finance and Investments':'Fin&Inv','Food & Beverage':'food'},inplace=True)
# Out:
# C:\Users\jbt\AppData\Local\Temp\ipykernel_29792\759969931.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['business_category'].replace({'Finance and Investments':'Fin&Inv','Food & Beverage':'food'},inplace=True)

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df['business_industries']=df['business_industries'].str.replace("['","")

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df['business_industries'].str.replace("']","")
# Out:
# 0                    Technology
# 1                    Technology
# 2       Finance and Investments
# 3              Fashion & Retail
# 4                       Telecom
#                  ...
# 2635                 Healthcare
# 2636            Food & Beverage
# 2637              Manufacturing
# 2638                Real Estate
# 2639                Diversified
# Name: business_industries, Length: 10601, dtype: object

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df['business_industries']=df['business_industries'].str.replace("']","")

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df.describe(include='all')
# Out:
#                 year         month          rank  net_worth(B) full_name  \
# count   10601.000000  10601.000000  10601.000000  10601.000000     10601
# unique           NaN           NaN           NaN           NaN      3048
# top              NaN           NaN           NaN           NaN     Li Li
# freq             NaN           NaN           NaN           NaN         9
# mean     2021.125083      3.821243   1155.165267      4.734218       NaN
# std         1.404781      0.383167    698.387482      9.597135       NaN
# min      2019.000000      3.000000      1.000000      1.000000       NaN
# 25%      2020.000000      4.000000    552.000000      1.500000       NaN
# 50%      2021.000000      4.000000   1116.000000      2.400000       NaN
# 75%      2022.000000      4.000000   1725.000000      4.300000       NaN
# max      2023.000000      4.000000   2674.000000    219.000000       NaN
#
#         birth_date           age gender country_of_citizenship  \
# ...

# %%
df['country_of_citizenship'].value_counts()
# Out:
# country_of_citizenship
# United States    3092
# China            1893
# India             559
# Germany           490
# Russia            457
#                  ...
# Macao               1
# Belize              1
# Barbados            1
# Estonia             1
# Armenia             1
# Name: count, Length: 80, dtype: int64

# %%
df['full_name'].value_counts()
# Out:
# full_name
# Li Li                    9
# Wang Yanqing & family    8
# Robert Miller            6
# John Mars                5
# Jacqueline Mars          5
#                         ..
# Sun Hongjun              1
# Rao Wei & family         1
# Adrian Paval             1
# Sjamsul Nursalim         1
# Soichiro Minami          1
# Name: count, Length: 3048, dtype: int64

# %%
x=df['country_of_citizenship'].value_counts()

# %%
x
# Out:
# country_of_citizenship
# United States    3092
# China            1893
# India             559
# Germany           490
# Russia            457
#                  ...
# Macao               1
# Belize              1
# Barbados            1
# Estonia             1
# Armenia             1
# Name: count, Length: 80, dtype: int64

# %%
x.index
# Out:
# Index(['United States', 'China', 'India', 'Germany', 'Russia', 'Hong Kong',
#        'Canada', 'Brazil', 'United Kingdom', 'Italy', 'Australia', 'France',
#        'Taiwan', 'Switzerland', 'Sweden', 'South Korea', 'Japan', 'Spain',
#        'Turkey', 'Thailand', 'Israel', 'Singapore', 'Indonesia', 'Philippines',
#        'Norway', 'Mexico', 'Malaysia', 'Netherlands', 'Ireland', 'Chile',
#        'Austria', 'Denmark', 'Finland', 'Ukraine', 'Egypt', 'Lebanon',
#        'Cyprus', 'Poland', 'Kazakhstan', 'Vietnam', 'Czech Republic',
#        'South Africa', 'Argentina', 'Peru', 'Greece', 'Monaco', 'Czechia',
#        'Nigeria', 'Colombia', 'Romania', 'New Zealand', 'United Arab Emirates',
#        'Morocco', 'Slovakia', 'Hungary', 'Qatar', 'St. Kitts and Nevis',
#        'Oman', 'Georgia', 'Venezuela', 'Iceland', 'Portugal', 'Liechtenstein',
#        'Zimbabwe', 'Nepal', 'Tanzania', 'Guernsey', 'Belgium', 'Algeria',
# ...

# %%
x.values
# Out:
# array([3092, 1893,  559,  490,  457,  303,  243,  234,  224,  189,  186,
#         186,  185,  176,  172,  162,  155,  129,  122,  116,  109,  106,
#          96,   66,   63,   62,   62,   49,   42,   41,   40,   39,   32,
#          31,   30,   30,   28,   27,   25,   25,   23,   23,   20,   18,
#          17,   17,   16,   16,   15,   12,   11,   10,    9,    9,    8,
#           8,    7,    7,    7,    6,    6,    5,    5,    5,    5,    5,
#           5,    5,    5,    4,    4,    2,    2,    2,    1,    1,    1,
#           1,    1,    1])

# %%
x.sort_values(ascending=False)
# Out:
# country_of_citizenship
# United States    3092
# China            1893
# India             559
# Germany           490
# Russia            457
#                  ...
# Macao               1
# Belize              1
# Barbados            1
# Estonia             1
# Armenia             1
# Name: count, Length: 80, dtype: int64

# %%
#הציגו את 10 המדינות בעלות הרווחים הגדולים ביותר 
#country_of_resiodance
df.groupby('country_of_residence')['net_worth(B)'].sum()
# Out:
# country_of_residence
# Algeria             22.4
# Angola               3.7
# Argentina           30.5
# Armenia              1.2
# Australia          697.3
#                   ...
# United States    18978.6
# Uruguay             12.8
# Uzbekistan          14.4
# Venezuela            7.2
# Vietnam             68.4
# Name: net_worth(B), Length: 82, dtype: float64

# %%
df.groupby('country_of_residence')['net_worth(B)'].sum().sort_values(ascending=False).head(10).reset_index(name='sumOfWorth')
# Out:
#   country_of_residence  sumOfWorth
# 0        United States    18978.60
# 1                China     8006.15
# 2                India     2310.30
# 3              Germany     1941.00
# 4               France     1813.50
# 5               Russia     1754.70
# 6       United Kingdom     1589.70
# 7            Hong Kong     1527.90
# 8          Switzerland     1349.70
# 9               Canada      701.30

# %%
df.groupby('country_of_residence')['net_worth(B)'].sum().sort_values(ascending=False).head(10)
# Out:
# country_of_residence
# United States     18978.60
# China              8006.15
# India              2310.30
# Germany            1941.00
# France             1813.50
# Russia             1754.70
# United Kingdom     1589.70
# Hong Kong          1527.90
# Switzerland        1349.70
# Canada              701.30
# Name: net_worth(B), dtype: float64

# %%
df.groupby('year')[['year','full_name','net_worth(B)']].head()

# %%
df.head()
# Out:
#    year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0  2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1  2019      3     2          96.5                 Bill Gates  28/10/1955
# 2  2019      3     3          82.5             Warren Buffett  30/08/1930
# 3  2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4  2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
#
#    age gender country_of_citizenship country_of_residence city_of_residence  \
# 0   55   Male          United States        United States           Seattle
# 1   63   Male          United States        United States            Medina
# 2   88   Male          United States        United States             Omaha
# 3   70   Male                 France               France             Paris
# 4   79   Male                 Mexico               Mexico       Mexico City
#
# ...

# %%
df.groupby('year')[['full_name','net_worth(B)']].head()
# Out:
#                    full_name  net_worth(B)
# 0                 Jeff Bezos         131.0
# 1                 Bill Gates          96.5
# 2             Warren Buffett          82.5
# 3   Bernard Arnault & family          76.0
# 4  Carlos Slim Helu & family          64.0
# 0                 Jeff Bezos         113.0
# 1                 Bill Gates          98.0
# 2   Bernard Arnault & family          76.0
# 3             Warren Buffett          67.5
# 4              Larry Ellison          59.0
# 0                 Jeff Bezos         177.0
# 1                  Elon Musk         151.0
# 2   Bernard Arnault & family         150.0
# 3                 Bill Gates         124.0
# 4            Mark Zuckerberg          97.0
# 0                  Elon Musk         219.0
# 1                 Jeff Bezos         171.0
# 2   Bernard Arnault & family         158.0
# 3                 Bill Gates         129.0
# 4             Warren Buffett         118.0
# 0   Bernard Arnault & family         211.0
# ...

# %%
df.groupby('full_name')[['full_name','net_worth(B)']].head()
# Out:
#                       full_name  net_worth(B)
# 0                    Jeff Bezos         131.0
# 1                    Bill Gates          96.5
# 2                Warren Buffett          82.5
# 3      Bernard Arnault & family          76.0
# 4     Carlos Slim Helu & family          64.0
# ...                         ...           ...
# 2635                    Yu Rong           1.0
# 2636     Richard Yuengling, Jr.           1.0
# 2637              Zhang Gongyun           1.0
# 2638     Zhang Guiping & family           1.0
# 2639                Inigo Zobel           1.0
#
# [10593 rows x 2 columns]

# %%
df.groupby('full_name')['net_worth(B)'].sum().sort_values(ascending=False).head()
# Out:
# full_name
# Jeff Bezos                  706.0
# Bernard Arnault & family    671.0
# Elon Musk                   596.9
# Bill Gates                  551.5
# Warren Buffett              470.0
# Name: net_worth(B), dtype: float64

# %%
df.groupby('full_name')['net_worth(B)'].sum()
# Out:
# full_name
# A. Jayson Adair                 2.4
# Abdulla Al Futtaim & family     4.9
# Abdulsamad Rabiu               24.5
# Abhay Firodia                  11.3
# Abhay Vakil & family            4.6
#                                ...
# Zong Qinghou                   41.5
# Zugen Ni                        5.5
# Zuo Hui                        20.3
# Zuowen Song                    11.3
# Zygmunt Solorz-Zak             13.2
# Name: net_worth(B), Length: 3048, dtype: float64

# %%
df.shape
# Out:
# (10601, 15)

# %%
df.groupby('full_name').size().sort_values()
# Out:
# full_name
# Huh Jae-myung            1
# Hubertus Benteler        1
# Huang Wenbiao            1
# Huang Weibin             1
# Huang Shan               1
#                         ..
# Zhu Xingliang            5
# Zygmunt Solorz-Zak       5
# Robert Miller            6
# Wang Yanqing & family    8
# Li Li                    9
# Length: 3048, dtype: int64

# %%
#בכל שנה רווח מקסימלי,רווח מינימלי,חציון ומה הגיל הממוצע 
df.groupby('year').agg({'net_worth(B)':['max','min','median'], 'age':['mean']})
# Out:
#      net_worth(B)                    age
#               max  min median       mean
# year
# 2019        131.0  1.0    2.3  64.773615
# 2020        113.0  1.0    2.2  64.994644
# 2021        177.0  1.0    2.6  65.010536
# 2022        219.0  1.0    2.5  65.001717
# 2023        211.0  1.0    2.5  65.572841

# %%
df[['full_name','net_worth(B)']].groupby('full_name')

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      9429
# Female    1172
# Name: count, dtype: int64

# %%
plt.pie(x=df['gender'].value_counts().values,labels=df['gender'].value_counts().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x222265c9950>,
# ...
#  [Text(-1.034316959154596, 0.37441745152328276, 'Male'),
#   Text(1.0343168133509786, -0.37441785430114993, 'Female')],
#  [Text(-0.5641728868115977, 0.2042277008308815, '88.9%'),
#   Text(0.5641728072823519, -0.20422792052789993, '11.1%')])

# %%
df['age'].value_counts()
# Out:
# age
# 58     321
# 57     313
# 59     310
# 67     310
# 65     305
#       ...
# 100      2
# 23       2
# 22       2
# 24       2
# 101      2
# Name: count, Length: 80, dtype: int64

# %%
df.groupby('age').size()
# Out:
# age
# 22      2
# 23      2
# 24      2
# 25      4
# 26      4
#        ..
# 97     11
# 98      8
# 99      7
# 100     2
# 101     2
# Length: 80, dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(x=df.groupby('age').size().index,y=df.groupby('age').size().values)
# Out:
# <Axes: xlabel='age'>

# %%
tt=df['business_category'].value_counts()
plt.figure(figsize=(14,10))
sns.barplot(x=tt.values,y=tt.index)
plt.xlabel('count',rotation=90)
# Out:
# Text(0.5, 0, 'count')

# %%
tt
# Out:
# business_category
# Finance & Investments         1253
# Technology                    1213
# Manufacturing                 1109
# Fashion & Retail              1072
# Real Estate                    914
# Diversified                    817
# Healthcare                     759
# food                           665
# Energy                         416
# Media & Entertainment          377
# Metals & Mining                307
# Fin&Inv                        287
# Service                        282
# Automotive                     261
# Construction & Engineering     188
# Logistics                      155
# Food and Beverage              148
# Telecom                        144
# Sports                         117
# Gambling & Casinos             116
# Name: count, dtype: int64

# %%
df
# Out:
#       year  month  rank  net_worth(B)                  full_name  birth_date  \
# 0     2019      3     1         131.0                 Jeff Bezos  12/01/1964
# 1     2019      3     2          96.5                 Bill Gates  28/10/1955
# 2     2019      3     3          82.5             Warren Buffett  30/08/1930
# 3     2019      3     4          76.0   Bernard Arnault & family  05/03/1949
# 4     2019      3     5          64.0  Carlos Slim Helu & family  28/01/1940
# ...    ...    ...   ...           ...                        ...         ...
# 2635  2023      4  2540           1.0                    Yu Rong  14/12/1971
# 2636  2023      4  2540           1.0     Richard Yuengling, Jr.  10/03/1943
# 2637  2023      4  2540           1.0              Zhang Gongyun  18/12/1962
# 2638  2023      4  2540           1.0     Zhang Guiping & family  21/08/1951
# 2639  2023      4  2540           1.0                Inigo Zobel  01/11/1956
#
# ...

# %%
df['wealth_status'].value_counts()
# Out:
# wealth_status
# Increased           4628
# Decreased           4412
# Remained Even       1155
# Returned to List     406
# Name: count, dtype: int64

# %%
sns.barplot(x=df['wealth_status'].value_counts().index,y=df['wealth_status'].value_counts().values,hue='year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 sns.barplot(x=df['wealth_status'].value_counts().index,y=df['wealth_status'].value_counts().values,hue='year')
#
# File C:\Python\Python313\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
#    2350 if ax is None:
# ...

# %%
eyal=df.groupby('year')['wealth_status'].value_counts().reset_index(name='count')

# %%
eyal
# Out:
#     year     wealth_status  count
# 0   2019         Decreased    965
# 1   2019         Increased    642
# 2   2019     Remained Even    266
# 3   2019  Returned to List     22
# 4   2020         Decreased   1033
# 5   2020         Increased    571
# 6   2020     Remained Even    213
# 7   2020  Returned to List     50
# 8   2021         Increased   1572
# 9   2021  Returned to List    239
# 10  2021         Decreased    201
# 11  2021     Remained Even    171
# 12  2022         Decreased   1029
# 13  2022         Increased   1019
# 14  2022     Remained Even    249
# 15  2022  Returned to List     32
# 16  2023         Decreased   1184
# 17  2023         Increased    824
# 18  2023     Remained Even    256
# 19  2023  Returned to List     63

# %%
eyal=df.groupby('year')['wealth_status'].value_counts().reset_index(name='count')
sns.barplot(data=eyal,x='wealth_status',y='count',hue='year',palette='bright')
# Out:
# <Axes: xlabel='wealth_status', ylabel='count'>

# %%
#בדקו את התפתחות התעשיות כמה מיליוןנרים היו בכל תעשייה בכל אחת מהשנים . תצוגה גרפית 
temp=df.groupby(['year','business_category']).size().reset_index(name='count')

# %%
plt.figure(figsize=(14,10))
sns.barplot(data=temp,y='business_category',x='count',hue='year')
# Out:
# <Axes: xlabel='count', ylabel='business_category'>
